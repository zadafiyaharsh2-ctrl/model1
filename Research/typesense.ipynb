# %%
import typesense
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
typesense_api_key= os.getenv("API_KEY_TYPESENSE")

# %%
client = typesense.Client({
    'nodes': [{
        'host' : '8a5wnxyt2oh9p-1.a1.typesense.net',
        'port' : '443',
        'protocol' : 'https'
    }],
    'api_key' : typesense_api_key,
    'connection_timeout_seconds' : 2
})

books_schema = {
    'name': 'books',
    'fields' : [
        { 'name' : 'title', 'type' : 'string' },
        { 'name' : 'authors', 'type' : 'string[]', 'facet' : True },
        { 'name' : 'publication_year', 'type' : 'int32', 'facet' : True },
        { 'name' : 'rating_count', 'type' : 'int32' },
        { 'name' : 'average_count', 'type' : 'float' }
    ],
    'default_sorting_field' : 'rating_count'
}
print(client.collections.create(books_schema))
# Out:
# Deprecation warning: AnalyticsRulesV1 is deprecated on v30+. Use client.analytics instead.
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connection.py:704, in HTTPSConnection.connect(self)
#     703 sock: socket.socket | ssl.SSLSocket
# --> 704 self.sock = sock = self._new_conn()
#     705 server_hostname: str = self.host
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connection.py:205, in HTTPConnection._new_conn(self)
#     204 except socket.gaierror as e:
# --> 205     raise NameResolutionError(self.host, self, e) from e
#     206 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x000002703312A270>: Failed to resolve '8a5wnxyt2oh9p-1.a1.typesense.net' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='8a5wnxyt2oh9p-1.a1.typesense.net', port=443): Max retries exceeded with url: /collections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002703312A270>: Failed to resolve '8a5wnxyt2oh9p-1.a1.typesense.net' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\api_call.py:451, in ApiCall._execute_request(self, fn, endpoint, entity_type, as_json, last_exception, num_retries, **kwargs)
#     450 try:
# --> 451     return self._make_request_and_process_response(
#     452         fn,
#     453         url,
#     454         entity_type,
#     455         as_json,
#     456         **kwargs,
#     457     )
#     458 except _SERVER_ERRORS as server_error:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\api_call.py:479, in ApiCall._make_request_and_process_response(self, fn, url, entity_type, as_json, **kwargs)
#     478 """Make the API request and process the response."""
# --> 479 request_response = self.request_handler.make_request(
#     480     fn=fn,
#     481     url=url,
#     482     as_json=as_json,
#     483     entity_type=entity_type,
#     484     **kwargs,
#     485 )
#     486 self.node_manager.set_node_health(self.node_manager.get_node(), is_healthy=True)
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\request_handler.py:218, in RequestHandler.make_request(self, fn, url, entity_type, as_json, **kwargs)
#     216     kwargs["data"] = json.dumps(kwargs["data"])
# --> 218 response = fn(url, **kwargs)
#     220 if response.status_code < 200 or response.status_code >= 300:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     627 r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629 :param url: URL for the new :class:`Request` object.
#    (...)    634 :rtype: requests.Response
#     635 """
# --> 637 return self.request("POST", url, data=data, json=json, **kwargs)
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\adapters.py:677, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     675         raise SSLError(e, request=request)
# --> 677     raise ConnectionError(e, request=request)
#     679 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='8a5wnxyt2oh9p-1.a1.typesense.net', port=443): Max retries exceeded with url: /collections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000002703312A270>: Failed to resolve '8a5wnxyt2oh9p-1.a1.typesense.net' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connection.py:704, in HTTPSConnection.connect(self)
#     703 sock: socket.socket | ssl.SSLSocket
# --> 704 self.sock = sock = self._new_conn()
#     705 server_hostname: str = self.host
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connection.py:205, in HTTPConnection._new_conn(self)
#     204 except socket.gaierror as e:
# --> 205     raise NameResolutionError(self.host, self, e) from e
#     206 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x0000027033086350>: Failed to resolve '8a5wnxyt2oh9p-1.a1.typesense.net' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='8a5wnxyt2oh9p-1.a1.typesense.net', port=443): Max retries exceeded with url: /collections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000027033086350>: Failed to resolve '8a5wnxyt2oh9p-1.a1.typesense.net' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\api_call.py:451, in ApiCall._execute_request(self, fn, endpoint, entity_type, as_json, last_exception, num_retries, **kwargs)
#     450 try:
# --> 451     return self._make_request_and_process_response(
#     452         fn,
#     453         url,
#     454         entity_type,
#     455         as_json,
#     456         **kwargs,
#     457     )
#     458 except _SERVER_ERRORS as server_error:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\api_call.py:479, in ApiCall._make_request_and_process_response(self, fn, url, entity_type, as_json, **kwargs)
#     478 """Make the API request and process the response."""
# --> 479 request_response = self.request_handler.make_request(
#     480     fn=fn,
#     481     url=url,
#     482     as_json=as_json,
#     483     entity_type=entity_type,
#     484     **kwargs,
#     485 )
#     486 self.node_manager.set_node_health(self.node_manager.get_node(), is_healthy=True)
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\request_handler.py:218, in RequestHandler.make_request(self, fn, url, entity_type, as_json, **kwargs)
#     216     kwargs["data"] = json.dumps(kwargs["data"])
# --> 218 response = fn(url, **kwargs)
#     220 if response.status_code < 200 or response.status_code >= 300:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     627 r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629 :param url: URL for the new :class:`Request` object.
#    (...)    634 :rtype: requests.Response
#     635 """
# --> 637 return self.request("POST", url, data=data, json=json, **kwargs)
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\adapters.py:677, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     675         raise SSLError(e, request=request)
# --> 677     raise ConnectionError(e, request=request)
#     679 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='8a5wnxyt2oh9p-1.a1.typesense.net', port=443): Max retries exceeded with url: /collections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000027033086350>: Failed to resolve '8a5wnxyt2oh9p-1.a1.typesense.net' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connection.py:704, in HTTPSConnection.connect(self)
#     703 sock: socket.socket | ssl.SSLSocket
# --> 704 self.sock = sock = self._new_conn()
#     705 server_hostname: str = self.host
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connection.py:205, in HTTPConnection._new_conn(self)
#     204 except socket.gaierror as e:
# --> 205     raise NameResolutionError(self.host, self, e) from e
#     206 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x0000027033086990>: Failed to resolve '8a5wnxyt2oh9p-1.a1.typesense.net' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='8a5wnxyt2oh9p-1.a1.typesense.net', port=443): Max retries exceeded with url: /collections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000027033086990>: Failed to resolve '8a5wnxyt2oh9p-1.a1.typesense.net' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\api_call.py:451, in ApiCall._execute_request(self, fn, endpoint, entity_type, as_json, last_exception, num_retries, **kwargs)
#     450 try:
# --> 451     return self._make_request_and_process_response(
#     452         fn,
#     453         url,
#     454         entity_type,
#     455         as_json,
#     456         **kwargs,
#     457     )
#     458 except _SERVER_ERRORS as server_error:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\api_call.py:479, in ApiCall._make_request_and_process_response(self, fn, url, entity_type, as_json, **kwargs)
#     478 """Make the API request and process the response."""
# --> 479 request_response = self.request_handler.make_request(
#     480     fn=fn,
#     481     url=url,
#     482     as_json=as_json,
#     483     entity_type=entity_type,
#     484     **kwargs,
#     485 )
#     486 self.node_manager.set_node_health(self.node_manager.get_node(), is_healthy=True)
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\request_handler.py:218, in RequestHandler.make_request(self, fn, url, entity_type, as_json, **kwargs)
#     216     kwargs["data"] = json.dumps(kwargs["data"])
# --> 218 response = fn(url, **kwargs)
#     220 if response.status_code < 200 or response.status_code >= 300:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     627 r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629 :param url: URL for the new :class:`Request` object.
#    (...)    634 :rtype: requests.Response
#     635 """
# --> 637 return self.request("POST", url, data=data, json=json, **kwargs)
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\adapters.py:677, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     675         raise SSLError(e, request=request)
# --> 677     raise ConnectionError(e, request=request)
#     679 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='8a5wnxyt2oh9p-1.a1.typesense.net', port=443): Max retries exceeded with url: /collections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000027033086990>: Failed to resolve '8a5wnxyt2oh9p-1.a1.typesense.net' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# gaierror                                  Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connection.py:704, in HTTPSConnection.connect(self)
#     703 sock: socket.socket | ssl.SSLSocket
# --> 704 self.sock = sock = self._new_conn()
#     705 server_hostname: str = self.host
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connection.py:205, in HTTPConnection._new_conn(self)
#     204 except socket.gaierror as e:
# --> 205     raise NameResolutionError(self.host, self, e) from e
#     206 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x0000027033086D50>: Failed to resolve '8a5wnxyt2oh9p-1.a1.typesense.net' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='8a5wnxyt2oh9p-1.a1.typesense.net', port=443): Max retries exceeded with url: /collections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000027033086D50>: Failed to resolve '8a5wnxyt2oh9p-1.a1.typesense.net' ([Errno 11001] getaddrinfo failed)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[3], line 22
#       1 client = typesense.Client({
#       2     'nodes': [{
#       3         'host' : '8a5wnxyt2oh9p-1.a1.typesense.net',
#    (...)      8     'connection_timeout_seconds' : 2
#       9 })
#      11 books_schema = {
#      12     'name': 'books',
#      13     'fields' : [
#    (...)     20     'default_sorting_field' : 'rating_count'
#      21 }
# ---> 22 print(client.collections.create(books_schema))
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\collections.py:137, in Collections.create(self, schema)
#     112 def create(self, schema: CollectionCreateSchema) -> CollectionSchema:
#     113     """
#     114     Create a new collection in Typesense.
#     115
#    (...)    135         >>> created_schema = collections.create(schema)
#     136     """
# --> 137     call: CollectionSchema = self.api_call.post(
#     138         endpoint=Collections.resource_path,
#     139         entity_type=CollectionSchema,
#     140         as_json=True,
#     141         body=schema,
#     142     )
#     143     return call
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\api_call.py:240, in ApiCall.post(self, endpoint, entity_type, as_json, params, body)
#     220 def post(
#     221     self,
#     222     endpoint: str,
#    (...)    226     body: typing.Union[TBody, None] = None,
#     227 ) -> typing.Union[str, TEntityDict]:
#     228     """
#     229     Execute a POST request to the Typesense API.
#     230
#    (...)    238         Union[TEntityDict, str]: The response, either as a JSON object or a string.
#     239     """
# --> 240     return self._execute_request(
#     241         session.post,
#     242         endpoint,
#     243         entity_type,
#     244         as_json,
#     245         params=params,
#     246         data=body,
#     247     )
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\api_call.py:460, in ApiCall._execute_request(self, fn, endpoint, entity_type, as_json, last_exception, num_retries, **kwargs)
#     458 except _SERVER_ERRORS as server_error:
#     459     self.node_manager.set_node_health(node, is_healthy=False)
# --> 460     return self._execute_request(
#     461         fn,
#     462         endpoint,
#     463         entity_type,
#     464         as_json,
#     465         last_exception=server_error,
#     466         num_retries=num_retries + 1,
#     467         **kwargs,
#     468     )
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\api_call.py:460, in ApiCall._execute_request(self, fn, endpoint, entity_type, as_json, last_exception, num_retries, **kwargs)
#     458 except _SERVER_ERRORS as server_error:
#     459     self.node_manager.set_node_health(node, is_healthy=False)
# --> 460     return self._execute_request(
#     461         fn,
#     462         endpoint,
#     463         entity_type,
#     464         as_json,
#     465         last_exception=server_error,
#     466         num_retries=num_retries + 1,
#     467         **kwargs,
#     468     )
#
#     [... skipping similar frames: ApiCall._execute_request at line 460 (1 times)]
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\api_call.py:460, in ApiCall._execute_request(self, fn, endpoint, entity_type, as_json, last_exception, num_retries, **kwargs)
#     458 except _SERVER_ERRORS as server_error:
#     459     self.node_manager.set_node_health(node, is_healthy=False)
# --> 460     return self._execute_request(
#     461         fn,
#     462         endpoint,
#     463         entity_type,
#     464         as_json,
#     465         last_exception=server_error,
#     466         num_retries=num_retries + 1,
#     467         **kwargs,
#     468     )
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\api_call.py:445, in ApiCall._execute_request(self, fn, endpoint, entity_type, as_json, last_exception, num_retries, **kwargs)
#     443 if num_retries > self.config.num_retries:
#     444     if last_exception:
# --> 445         raise last_exception
#     446     raise TypesenseClientError("All nodes are unhealthy")
#     448 node, url, kwargs = self._prepare_request_params(endpoint, **kwargs)
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\api_call.py:451, in ApiCall._execute_request(self, fn, endpoint, entity_type, as_json, last_exception, num_retries, **kwargs)
#     448 node, url, kwargs = self._prepare_request_params(endpoint, **kwargs)
#     450 try:
# --> 451     return self._make_request_and_process_response(
#     452         fn,
#     453         url,
#     454         entity_type,
#     455         as_json,
#     456         **kwargs,
#     457     )
#     458 except _SERVER_ERRORS as server_error:
#     459     self.node_manager.set_node_health(node, is_healthy=False)
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\api_call.py:479, in ApiCall._make_request_and_process_response(self, fn, url, entity_type, as_json, **kwargs)
#     470 def _make_request_and_process_response(
#     471     self,
#     472     fn: typing.Callable[..., requests.models.Response],
#    (...)    476     **kwargs: SessionFunctionKwargs[TParams, TBody],
#     477 ) -> typing.Union[TEntityDict, str]:
#     478     """Make the API request and process the response."""
# --> 479     request_response = self.request_handler.make_request(
#     480         fn=fn,
#     481         url=url,
#     482         as_json=as_json,
#     483         entity_type=entity_type,
#     484         **kwargs,
#     485     )
#     486     self.node_manager.set_node_health(self.node_manager.get_node(), is_healthy=True)
#     487     return (
#     488         typing.cast(TEntityDict, request_response)
#     489         if as_json
#     490         else typing.cast(str, request_response)
#     491     )
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\typesense\request_handler.py:218, in RequestHandler.make_request(self, fn, url, entity_type, as_json, **kwargs)
#     215 if kwargs.get("data") and not isinstance(kwargs["data"], (str, bytes)):
#     216     kwargs["data"] = json.dumps(kwargs["data"])
# --> 218 response = fn(url, **kwargs)
#     220 if response.status_code < 200 or response.status_code >= 300:
#     221     error_message = self._get_error_message(response)
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)    634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\jeeva\.conda\envs\LLM\Lib\site-packages\requests\adapters.py:677, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     673     if isinstance(e.reason, _SSLError):
#     674         # This branch is for urllib3 v1.22 and later.
#     675         raise SSLError(e, request=request)
# --> 677     raise ConnectionError(e, request=request)
#     679 except ClosedPoolError as e:
#     680     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='8a5wnxyt2oh9p-1.a1.typesense.net', port=443): Max retries exceeded with url: /collections (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000027033086D50>: Failed to resolve '8a5wnxyt2oh9p-1.a1.typesense.net' ([Errno 11001] getaddrinfo failed)"))

# %%
client

# %% [markdown]
# #### NEXT

# %%
with open('books.jsonl', 'r', encoding='utf-8') as jsonl_file:
    data = jsonl_file.read()
    client.collections['books'].documents.import_(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 with open('books.jsonl', 'r', encoding='utf-8') as jsonl_file:
#       2     data = jsonl_file.read()
#       3     client.collections['books'].documents.import_(data)
#
# File d:\anaconda3\envs\LLM\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'books.jsonl'

# %%
search_parameters={
    'q' : "harry potter",
    'query_by' : "title, author",
    'sort_by' : "ratings_count:desc",
}

client.collections['books'].documents.search(search_parameters=search_parameters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 7
#       1 search_parameters={
#       2     'q' : "harry potter",
#       3     'query_by' : "title, author",
#       4     'sort_by' : "ratings_count:desc",
#       5 }
# ----> 7 client.collections['books'].documents.search(search_parameters=search_parameters)
#
# NameError: name 'client' is not defined

# %%
search_parameters={
    'q' : "harry potter",
    'query_by' : 'title',
    'filter_by' : 'publication_year:<1998',
    'sort_by' : 'publication_year:desc'
}

client.collections['books'].documents.search(search_parameters=search_parameters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       1 search_parameters={
#       2     'q' : "harry potter",
#       3     'query_by' : 'title',
#       4     'filter_by' : 'publication_year:<1998',
#       5     'sort_by' : 'publication_year:desc'
#       6 }
# ----> 8 client.collections['books'].documents.search(search_parameters=search_parameters)
#
# NameError: name 'client' is not defined

# %%
search_parameters= {
    'q' : 'experiment',
    'query_by' : "title",
    'facet_by' : "authors",
    'sort_by' : 'average_rating:desc'
} 

client.collections["books"].documents.search(search_parameters=search_parameters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 8
#       1 search_parameters= {
#       2     'q' : 'experiment',
#       3     'query_by' : "title",
#       4     'facet_by' : "authors",
#       5     'sort_by' : 'average_rating:desc'
#       6 }
# ----> 8 client.collections["books"].documents.search(search_parameters=search_parameters)
#
# NameError: name 'client' is not defined

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import Typesense
from langchain_text_splitters import CharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain_groq import ChatGroq
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 4
#       2 from langchain_community.vectorstores import Typesense
#       3 from langchain_text_splitters import CharacterTextSplitter
# ----> 4 from langchain.embeddings import HuggingFaceEmbeddings
#       5 from langchain_groq import ChatGroq
#
# ImportError: cannot import name 'HuggingFaceEmbeddings' from 'langchain.embeddings' (d:\anaconda3\envs\LLM\Lib\site-packages\langchain\embeddings\__init__.py)

# %%
import os
os.environ['GROQ_API'] = ""

# %%
loader = TextLoader("text.txt")
documents = loader.load()
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
docs = text_splitter.split_documents(documents)

embeddings = HuggingFaceEmbeddings()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File d:\anaconda3\envs\LLM\Lib\site-packages\langchain_community\document_loaders\text.py:42, in TextLoader.lazy_load(self)
#      41 try:
# ---> 42     with open(self.file_path, encoding=self.encoding) as f:
#      43         text = f.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'text.txt'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 2
#       1 loader = TextLoader("text.txt")
# ----> 2 documents = loader.load()
#       3 text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
#       4 docs = text_splitter.split_documents(documents)
#
# File d:\anaconda3\envs\LLM\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File d:\anaconda3\envs\LLM\Lib\site-packages\langchain_community\document_loaders\text.py:58, in TextLoader.lazy_load(self)
#      56         raise RuntimeError(f"Error loading {self.file_path}") from e
#      57 except Exception as e:
# ---> 58     raise RuntimeError(f"Error loading {self.file_path}") from e
#      60 metadata = {"source": str(self.file_path)}
#      61 yield Document(page_content=text, metadata=metadata)
#
# RuntimeError: Error loading text.txt

# %%
docsearch = Typesense.from_documents(
    docs,
    embeddings,
    typesense_client_params = {
        "host" : "8a5wnxyt2pmjdoh9p-1.a1.typesense.net",
        "port" : "443",
        "protocol" : "https",
        "typesense_api_key" : typesense_api_key,
        "typesense_collection_name" : "lang-chain"
    }
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 docsearch = Typesense.from_documents(
# ----> 2     docs,
#       3     embeddings,
#       4     typesense_client_params = {
#       5         "host" : "8a5wnxyt2pmjdoh9p-1.a1.typesense.net",
#       6         "port" : "443",
#       7         "protocol" : "https",
#       8         "typesense_api_key" : typesense_api_key,
#       9         "typesense_collection_name" : "lang-chain"
#      10     }
#      11 )
#
# NameError: name 'docs' is not defined

# %%
query = "What is Artificial Intelligence?"
found_docs = docsearch.similarity_search(query)
print(found_docs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 query = "What is Artificial Intelligence?"
# ----> 2 found_docs = docsearch.similarity_search(query)
#       3 print(found_docs)
#
# NameError: name 'docsearch' is not defined

# %%
retriever = docsearch.as_retriever()
retriever
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 retriever = docsearch.as_retriever()
#       2 retriever
#
# NameError: name 'docsearch' is not defined

# %%
query = "Artificial Intelligence indepth explaination"
retriever.invoke(query)[0]
